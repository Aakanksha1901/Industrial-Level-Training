# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("operations.csv")
df
# Out:
# <ipython-input-2-4472c7920217>:5: DtypeWarning: Columns (7,8,11,13,31,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("operations.csv")
#         Mission ID Mission Date Theater of Operations      Country Air Force  \
# 0                1    8/15/1943                   MTO          USA     12 AF
# 1                2    8/15/1943                   PTO          USA      5 AF
# 2                3    8/15/1943                   MTO          USA     12 AF
# 3                4    8/15/1943                   MTO          USA     12 AF
# 4                5    8/15/1943                   PTO          USA      5 AF
# ...            ...          ...                   ...          ...       ...
# 178276      178738    2/16/1945                   CBI          USA     10 AF
# 178277      178739    2/16/1945                   CBI          USA     10 AF
# 178278      178740    2/16/1945                   CBI          USA     10 AF
# ...

# %%
df.head()
df.tail()
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178281 entries, 0 to 178280
# Data columns (total 46 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Mission ID                             178281 non-null  int64
#  1   Mission Date                           178281 non-null  object
#  2   Theater of Operations                  175123 non-null  object
#  3   Country                                126494 non-null  object
#  4   Air Force                              126444 non-null  object
#  5   Unit ID                                50913 non-null   object
#  6   Aircraft Series                        178165 non-null  object
#  7   Callsign                               21 non-null      object
#  8   Mission Type                           47186 non-null   object
#  9   Takeoff Base                           3383 non-null    object
# ...

# %%
df.describe().T
# Out:
#                                           count           mean            std  \
# Mission ID                             178281.0   89414.547041   51649.744549
# Takeoff Longitude                        2980.0     220.618627     454.046956
# Target Latitude                        169565.0      38.067793      18.711405
# Target Longitude                       169543.0      43.340213      59.681160
# Altitude (Hundreds of Feet)            120826.0     139.026812     186.818278
# Airborne Aircraft                       82242.0      12.329771      12.514833
# Attacking Aircraft                     125108.0      10.218899      11.246399
# Bombing Aircraft                        81612.0      12.347486      12.573549
# Aircraft Returned                         133.0       2.157895       1.369816
# Aircraft Failed                           247.0       4.275304       5.924758
# Aircraft Damaged                           38.0       2.052632       1.675699
# ...

# %%
df.isnull().sum()
# Out:
# Mission ID                                    0
# Mission Date                                  0
# Theater of Operations                      3158
# Country                                   51787
# Air Force                                 51837
# Unit ID                                  127368
# Aircraft Series                             116
# Callsign                                 178260
# Mission Type                             131095
# Takeoff Base                             174898
# Takeoff Location                         174943
# Takeoff Latitude                         175300
# Takeoff Longitude                        175301
# Target ID                                 50875
# Target Country                              599
# Target City                                2263
# Target Type                               31911
# Target Industry                           51802
# Target Priority                           43561
# Target Latitude                            8716
# ...

# %%
print("Duplicate row Count:" ,df.duplicated().sum())
# Out:
# Duplicate row Count: 0

# %%
df['Theater of Operations'] = df ['Theater of Operations'].fillna('NA')
print(df.isnull().sum())
# Out:
# Mission ID                                    0
# Mission Date                                  0
# Theater of Operations                         0
# Country                                   51787
# Air Force                                 51837
# Unit ID                                  127368
# Aircraft Series                             116
# Callsign                                 178260
# Mission Type                             131095
# Takeoff Base                             174898
# Takeoff Location                         174943
# Takeoff Latitude                         175300
# Takeoff Longitude                        175301
# Target ID                                 50875
# Target Country                              599
# Target City                                2263
# Target Type                               31911
# Target Industry                           51802
# Target Priority                           43561
# Target Latitude                            8716
# ...

# %%
df['Country'] = df['Country'].fillna('NA')

# %%
df['Air Force'] = df['Air Force'].fillna('NA')

# %%
df['Unit ID'] = df['Unit ID'].fillna('NA')

# %%
df['Aircraft Series'] = df['Aircraft Series'].fillna('NA')

# %%
df['Callsign'] = df['Callsign'].fillna('NA')

# %%
df['Mission Type'] = df['Mission Type'].fillna('NA')

# %%
df['Takeoff Base'] = df['Takeoff Base'].fillna('NA')

# %%
df['Takeoff Location'] = df['Takeoff Location'].fillna('NA')

# %%
df['Takeoff Latitude'] = df['Takeoff Latitude'].fillna('NA')

# %%
df['Takeoff Longitude'] = df['Takeoff Longitude'].fillna('NA')

# %%
df['Target ID']= df['Target ID'].fillna('NA')

# %%
df['Target Country']= df['Target Country'].fillna('Na')

# %%
df['Target City']= df['Target City'].fillna('NA')

# %%
df['Target Type']= df['Target Type'].fillna('NA')

# %%
df['Target Industry']= df['Target Industry'].fillna('NA')

# %%
df['Target Priority']= df['Target Priority'].fillna('NA')

# %%
df['Target Latitude'] = df['Target Latitude'].fillna('NA')

# %%
df['Target Longitude']= df['Target Longitude'].fillna('NA')

# %%
df['Altitude (Hundreds of Feet)']= df['Altitude (Hundreds of Feet)'].fillna(df['Altitude (Hundreds of Feet)']).mean()

# %%
df['Airborne Aircraft']=df['Airborne Aircraft'].fillna(df['Airborne Aircraft']).mean()

# %%
df['Attacking Aircraft']=df['Attacking Aircraft'].fillna(df['Attacking Aircraft']).mean()

# %%
df['Bombing Aircraft']=df['Bombing Aircraft'].fillna(df['Bombing Aircraft']).mean()

# %%
df['Aircraft Returned']=df['Aircraft Returned'].fillna(df['Aircraft Returned']).mean()

# %%
df['Aircraft Failed']=df['Aircraft Failed'].fillna(df['Aircraft Failed']).mean()

# %%
df['Aircraft Damaged']=df['Aircraft Damaged'].fillna(df['Aircraft Damaged']).mean()

# %%
df['Aircraft Lost']=df['Aircraft Lost'].fillna(df['Aircraft Lost']).mean()

# %%
df['High Explosives']=df['High Explosives'].fillna(df['High Explosives']).mean()

# %%
df['High Explosives Type']= df['High Explosives Type'].fillna('NA')

# %%
df['High Explosives Weight (Pounds)']= df['High Explosives Weight (Pounds)'].fillna('NA')

# %%
df['High Explosives Weight (Tons)']=df['High Explosives Weight (Tons)'].fillna(df['High Explosives Weight (Tons)']).mean()

# %%
df['Incendiary Devices']= df['Incendiary Devices'].fillna(df['Incendiary Devices']).mean()

# %%
df['Incendiary Devices Type']=df['Incendiary Devices Type'].fillna('NA')

# %%
df['Incendiary Devices Weight (Pounds)']=df['Incendiary Devices Weight (Pounds)'].fillna(df['Incendiary Devices Weight (Pounds)']).mean()

# %%
df['Incendiary Devices Weight (Tons)']=df['Incendiary Devices Weight (Tons)'].fillna(df['Incendiary Devices Weight (Tons)']).mean()

# %%
df['Fragmentation Devices']= df['Fragmentation Devices'].fillna(df['Fragmentation Devices']).mean()

# %%
df['Fragmentation Devices Type']=df['Fragmentation Devices Type'].fillna('NA')

# %%
df['Fragmentation Devices Weight (Pounds)']=df['Fragmentation Devices Weight (Pounds)'].fillna(df['Fragmentation Devices Weight (Pounds)']).mean()

# %%
df['Fragmentation Devices Weight (Tons)']=df['Fragmentation Devices Weight (Tons)'].fillna(df['Fragmentation Devices Weight (Tons)']).mean()

# %%
df['Total Weight (Pounds)']=df['Total Weight (Pounds)'].fillna(df['Total Weight (Pounds)']).mean()

# %%
df['Total Weight (Tons)']= df['Total Weight (Tons)'].fillna(df['Total Weight (Tons)']).mean()

# %%
df['Time Over Target']= df['Time Over Target'].fillna('NA')

# %%
df['Bomb Damage Assessment']=df['Bomb Damage Assessment'].fillna('NA')

# %%
df['Source ID']=df['Source ID'].fillna(df['Source ID']).mean()

# %%
print(df.isnull().sum())
# Out:
# Mission ID                               0
# Mission Date                             0
# Theater of Operations                    0
# Country                                  0
# Air Force                                0
# Unit ID                                  0
# Aircraft Series                          0
# Callsign                                 0
# Mission Type                             0
# Takeoff Base                             0
# Takeoff Location                         0
# Takeoff Latitude                         0
# Takeoff Longitude                        0
# Target ID                                0
# Target Country                           0
# Target City                              0
# Target Type                              0
# Target Industry                          0
# Target Priority                          0
# Target Latitude                          0
# Target Longitude                         0
# Altitude (Hundreds of Feet)              0
# ...

# %%
df.to_csv("cleaned_operation_data.csv", index=False)
